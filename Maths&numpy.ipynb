# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1605e990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1605ec10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d15f8a710>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1605ed50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1605ee90>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50,499]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d18261450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d182616d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d18261310>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d18261950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d18261a90>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
a=[10,25,33,36,59]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d182d51d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d182d5450>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d182d5090>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d182d56d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d182d5810>],
#  'means': []}

# %%
import seaborn as sns
a=[10,90,91,92,93,94]
sns.boxplot(a)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50,60,800]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1944f9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1944fc50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1944f890>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1944fed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1949c050>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
a=[10,20,30,40,50,60]
plt.boxplot(a)
Q1=25
Q3=55

# %%
IQR=Q3-Q1

# %%
print("Q1:",Q1)
print("Q3:",Q3)
print("IQR:",IQR)
# Out:
# Q1: 25
# Q3: 55
# IQR: 30

# %%
a=[9,12,23,44,56,78,88,99,100]

# %%
56
# Out:
# 56

# %%
Q1=12.5

# %% [markdown]
# min=9

# %%
Q3=88.5

# %%
max=100

# %%
IQR=88.5-12.5

# %%
IQR
# Out:
# 76.0

# %%
-105
# Out:
# -105

# %%
202.5
# Out:
# 202.5

# %%
a=[23,34,45,49,56,59,67,78,79,82,83,88,92,94,95,98]

# %%
median=78.5

# %%
min=23

# %%
max=98

# %%
Q1=49.5

# %%
Q3=88

# %%
IQR=38.5

# %%
a=[23,34,45,82,83,88,92,94,95,98,120,130,140]

# %%
import matplotlib.pyplot as plt
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1955b250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1955b4d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1955b110>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1955b750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1955b890>],
#  'means': []}

# %%
a=[12,18,25,28,45,67,78,88,99]

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1950f4d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1950f250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1950ee90>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1950efd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1950f610>],
#  'means': []}

# %%
a=[23,34,45,82,83,88,92,94,95,98,120,130,140]

# %%
min=23

# %%
max=140

# %%
median=92

# %%
Q1=45.5

# %%
Q3=98.5

# %% [raw]
# IQR=53

# %%
-34
# Out:
# -34

# %%
178
# Out:
# 178

# %%
a=[23,34,45,82,83,88,92,94,95,98,120,130,140]

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d195d6210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d195d6490>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d195d60d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d195d6710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d195d6850>],
#  'means': []}

# %%
a=[10,20,30,40,100]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1a645a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1a645d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1a645950>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1a645f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1a6460d0>],
#  'means': []}

# %%
a=[10,20,30,40,50,60]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1a6cc190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1a6cc410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1a6cc050>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1a6cc690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1a6cc7d0>],
#  'means': []}

# %%
import matplotlib.pyplot as plt
a=[10,70,80,90,100,110]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1a83b110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1a83b390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1a83afd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1a83b610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1a83b750>],
#  'means': []}

# %%
a=[10,20,30,40,50,100]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1a8a9a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1a8a9d10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1a8a9950>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1a8a9f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1a8aa0d0>],
#  'means': []}

# %%
a=[10,20,30,40,50]
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20d1a918410>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20d1a918690>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20d1a9182d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x20d1a918910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20d1a918a50>],
#  'means': []}

# %%
import numpy as np
a=[10,20,30,40,50]
b=np.array(a)
print(b)
# Out:
# [10 20 30 40 50]

# %%
import numpy as np
a=[[10,20,30],
   [40,50,60]]
b=np.array(a)
print(b)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
import numpy as np
a=[10,20,30,40,50]
b=np.array(a)
print(b[1])
print(b[3])
# Out:
# 20
# 40

# %%
import numpy as np
a=[10,20,30,40,50]
b=np.array(a)
for value in b:
    print(value)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
import numpy as np
a=np.matrix([[10,20,30,40,50],[80,90,100,110,120]])
print(a[0,0])
print(a[0,1])
print(a[0,2])
print(a[1,1])
# Out:
# 10
# 20
# 30
# 90

# %%
import numpy as np
a=[[10,20,30,40,50],[50,60,70,80,90]]
b=np.array(a)
print(b.ndim)
print(b.shape)
# Out:
# 2
# (2, 5)

# %%
import numpy as np
a=[10,20,30,40,50,60]
b=np.array(a)
print(b.reshape(1,6))
print(b.reshape(3,2))
print(b.reshape(2,3))
# Out:
# [[10 20 30 40 50 60]]
# [[10 20]
#  [30 40]
#  [50 60]]
# [[10 20 30]
#  [40 50 60]]

# %%
a=[[10,20,30],[40,50,60]]
b=np.array(a)
print(b.flatten())
# Out:
# [10 20 30 40 50 60]

# %%
a=[50,78,99,34,67]
b=np.array(a)
b.sort()
print(b)
# Out:
# [34 50 67 78 99]

# %%
import numpy as np
a=[[10,20,0],[0,40,50],[60,0,80]]
b=np.array(a)
result=np.count_nonzero(b)
print(result)
# Out:
# 6

# %%
import numpy as np
a=[10,20,30,40,50]
b=np.array(a)
print(b*2)
print(b+1)
# Out:
# [ 20  40  60  80 100]
# [11 21 31 41 51]

# %%
import numpy as np
a=np.array([[10,20,30],[40,50,60]])
print(a.diagonal())
# Out:
# [10 50]

# %%
import numpy as np
a=np.array([10,20,30])
b=np.array([40,50,60])
print(np.add(a,b))
# Out:
# [50 70 90]
